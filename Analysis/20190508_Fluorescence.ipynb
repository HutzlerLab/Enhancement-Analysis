# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import matplotlib.pyplot as plt
import numpy as np
import statistics as stat
import ipywidgets as widgets
from IPython.display import display
from enhancement_analysis import *
from fit_functions import *
from low_level import readCSVrows,writeCSVrows,calcEnhancement,readCSVcolumns
# %matplotlib inline

# %%
folder = '20190508'

# %%
from low_level import calculateSingleFluor,timeArray

# %%
time = timeArray(data[1])

# %%
arr = []
for i in range(480,492):
    data = calculateSingleFluor(folder,i,ch=1)
    integ=sliceIntegrate(data[0][0],time,[3,7.5])
    arr.append(integ)

# %%
freq=np.array([-0.143,-0.141,-0.145,-0.148,-0.138,-0.142,-0.135,-0.151,-0.155,-0.131,-0.127,-0.159])*1500
arr = np.array(arr)

# %%
fluor = np.array(sortData(freq,arr))
freq_sort = np.array(sorted(freq))

# %%
plt.plot(freq_sort,fluor)

# %%
params,errors,residuals = fitGaussian(freq_sort,fluor,verbose=True)
# Out:
# Fit error =  [1.349552 0.750951 0.147746 0.14595 ]
# FIT PARAMS =  [   9.400831 -215.472733    1.494459    0.336037]
# Mean = -215.472733 +/- 0.750951 MHz, StDev = 9.400831 +/- 1.349552 MHz
